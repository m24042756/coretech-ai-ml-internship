# %% [markdown]
# # Task 02 - Python Basics
# Name: Malaika Noor

# %%
name = "Malaika"
print(name)
# Out:
# Malaika

# %%
age = 20
print(age)
# Out:
# 20

# %%
height = 5.4
print(height)
# Out:
# 5.4

# %%
is_student = True
print(is_student)
# Out:
# True

# %%
fruits = ["Apple", "Mango", "Banana"]
print(fruits)
# Out:
# ['Apple', 'Mango', 'Banana']

# %%
fruits = ["Apple", "Mango", "Banana"]
print(fruits)
# Out:
# ['Apple', 'Mango', 'Banana']

# %%
student = {"Name":"Malaika", "Age":20}
print(student)
# Out:
# {'Name': 'Malaika', 'Age': 20}

# %%
a = 10
b = 5
print(a + b)
# Out:
# 15

# %%
print(a - b)
# Out:
# 5

# %%
age = 20

if age >= 18:
    print("Adult")
else:
    print("Minor")
# Out:
# Adult

# %%
for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i = 1

while i <= 5:
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def greet(name):
    return "Hello " + name

print(greet("Malaika"))
# Out:
# Hello Malaika

# %%
squares = [x*x for x in range(1,6)]
print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
import numpy as np

arr = np.array([1,2,3,4,5])

print(arr)
print(arr.mean())
# Out:
# [1 2 3 4 5]
# 3.0

# %%
import pandas as pd

data = {
    "Name":["Ali","Sara","Ahmed"],
    "Age":[20,21,22]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     Name  Age
# 0    Ali   20
# 1   Sara   21
# 2  Ahmed   22

# %%
import pandas as pd

students = {
    "Name":["Ahmed","Zubaida","Haris","Ayesha"],
    "Age":[20,21,22,23],
    "City":["Karachi","Lahore","Islamabad","Karachi"]
}

df = pd.DataFrame(students)

print(df)

print(df.info())

print(df.describe())
# Out:
#       Name  Age       City
# 0    Ahmed   20    Karachi
# 1  Zubaida   21     Lahore
# 2    Haris   22  Islamabad
# 3   Ayesha   23    Karachi
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   City    4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 228.0+ bytes
# None
#              Age
# count   4.000000
# mean   21.500000
# std     1.290994
# min    20.000000
# 25%    20.750000
# 50%    21.500000
# 75%    22.250000
# max    23.000000
